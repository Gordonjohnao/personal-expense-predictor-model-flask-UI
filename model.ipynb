# %% [markdown]
# ## Installing Dependencies and libraries

# %%
import numpy as np  ## used for working with arrays
import matplotlib.pyplot as plt ##  library for data visualizations
import pandas as pd  ## used to analyze data
import seaborn as sns  ## library for making statistical graphics in Python
import pickle ## used for serializing and de-serializing a Python object structure

# %matplotlib inline

# %% [markdown]
# ## Importing Training Dataset

# %%
dataset = pd.read_csv('dataset.csv')

# %% [markdown]
# ## Display data on top

# %%
dataset.head()
# Out:
#    Housing  Transport  Food  shopping  Payments  Entertainment  Utilities  \
# 0     5000       1500  4000       300        20             20       2000
# 1     5000       1200  2500       200        10            120       1300
# 2     6000       2300  1200        45       300             15        300
# 3     7500       1200   700         0       120            350        250
# 4     5000        200   500       570         0            100          0
#
#    Groceries  internet  others  total
# 0        200       250     120  13410
# 1        120       350       0  10800
# 2          0       350       0  10510
# 3        120       220       0  10460
# 4         40       270     500   7180

# %% [markdown]
# # Exploratory Data Analysis

# %%
dataset.info() ## print a concise summary of a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Housing        22 non-null     int64
#  1   Transport      22 non-null     int64
#  2   Food           22 non-null     int64
#  3   shopping       22 non-null     int64
#  4   Payments       22 non-null     int64
#  5   Entertainment  22 non-null     int64
#  6   Utilities      22 non-null     int64
#  7   Groceries      22 non-null     int64
#  8   internet       22 non-null     int64
#  9   others         22 non-null     int64
#  10  total          22 non-null     int64
# dtypes: int64(11)
# memory usage: 2.0 KB

# %%
dataset.describe() ##using the ‘describe’ function to  get a statistical view
## of the data like mean, median, standard deviation, and so on
# Out:
#            Housing    Transport         Food     shopping     Payments  \
# count    22.000000    22.000000    22.000000    22.000000    22.000000
# mean   5159.090909   548.181818  1160.318182   561.590909   465.000000
# std     564.555528   630.839474   788.329360  1677.090299  1409.243296
# min    5000.000000     0.000000   250.000000     0.000000     0.000000
# 25%    5000.000000   120.000000   700.000000     0.000000     0.000000
# 50%    5000.000000   225.000000  1050.000000   135.000000    90.000000
# 75%    5000.000000   900.000000  1200.000000   487.500000   285.000000
# max    7500.000000  2300.000000  4000.000000  8000.000000  6700.000000
#
#        Entertainment    Utilities   Groceries     internet      others  \
# count      22.000000    22.000000   22.000000    22.000000   22.000000
# mean       81.136364   315.454545  130.909091   387.681818  192.954545
# std       166.289563   518.254647   72.171033   248.101628  203.766084
# ...

# %% [markdown]
# ## DATA VISUALIZATION

# %% [markdown]
# ## Plot the statistical Representation of the data

# %%
# 1. Heatmap -find relations between variables in a dataset
corr = dataset.corr()
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(corr,cmap='BuPu',annot=True,fmt=".2f",ax=ax)
plt.title("Dependencies of Expense per week")
plt.savefig('./static/Cor')
plt.show()

# %%
# 2. Scatter plot- used to observe linear relations between two variables in a dataset

def scatter_dataset(y_var):
    scatter_df = dataset.drop(y_var, axis = 1)
    i = dataset.columns
    
    plot1 = sns.scatterplot(i[0], y_var, data = dataset, color = 'orange', edgecolor = 'b', s = 150)
    plt.title('{} / total'.format(i[0]), fontsize = 16)
    plt.xlabel('{}'.format(i[0]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter1.png')
    plt.show()
    
    plot2 = sns.scatterplot(i[1], y_var, data = dataset, color = 'yellow', edgecolor = 'b', s = 150)
    plt.title('{} / total'.format(i[1]), fontsize = 16)
    plt.xlabel('{}'.format(i[1]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter2.png')
    plt.show()
    
    plot3 = sns.scatterplot(i[2], y_var, data = dataset, color = 'aquamarine', edgecolor = 'b', s = 150)
    plt.title('{} / total'.format(i[2]), fontsize = 16)
    plt.xlabel('{}'.format(i[2]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter3.png')
    plt.show()
    
    plot4 = sns.scatterplot(i[3], y_var, data = dataset, color = 'deepskyblue', edgecolor = 'b', s = 150)
    plt.title('{} / total'.format(i[3]), fontsize = 16)
    plt.xlabel('{}'.format(i[3]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter4.png')
    plt.show()
    
    plot5 = sns.scatterplot(i[4], y_var, data = dataset, color = 'crimson', edgecolor = 'white', s = 150)
    plt.title('{} / total'.format(i[4]), fontsize = 16)
    plt.xlabel('{}'.format(i[4]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter5.png')
    plt.show()
    
    plot6 = sns.scatterplot(i[5], y_var, data = dataset, color = 'darkviolet', edgecolor = 'white', s = 150)
    plt.title('{} / total'.format(i[5]), fontsize = 16)
    plt.xlabel('{}'.format(i[5]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter6.png')
    plt.show()
    
    plot7 = sns.scatterplot(i[6], y_var, data = dataset, color = 'khaki', edgecolor = 'b', s = 150)
    plt.title('{} / total'.format(i[6]), fontsize = 16)
    plt.xlabel('{}'.format(i[6]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter7.png')
    plt.show()
    
    plot8 = sns.scatterplot(i[7], y_var, data = dataset, color = 'gold', edgecolor = 'b', s = 150)
    plt.title('{} / total'.format(i[7]), fontsize = 16)
    plt.xlabel('{}'.format(i[7]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter8.png')
    plt.show()
    
    plot9 = sns.scatterplot(i[8], y_var, data = dataset, color = 'r', edgecolor = 'b', s = 150)
    plt.title('{} / total'.format(i[8]), fontsize = 16)
    plt.xlabel('{}'.format(i[8]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter9.png')
    plt.show()
    
    plot10 = sns.scatterplot(i[9], y_var, data = dataset, color = 'deeppink', edgecolor = 'b', s = 150)
    plt.title('{} / total'.format(i[9]), fontsize = 16)
    plt.xlabel('{}'.format(i[9]), fontsize = 14)
    plt.ylabel('total Expense Per Week', fontsize = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.savefig('static/scatter10.png')
    plt.show()
    
scatter_dataset('total')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
dataset.tail() ## print the data from bottom
# Out:
#     Housing  Transport  Food  shopping  Payments  Entertainment  Utilities  \
# 17     5000        150  1200         0       560              0         80
# 18     5000        350  1300       500       145            560         50
# 19     5000        250   987         0       600              0        120
# 20     5000        500  1200         0       150              0          0
# 21     5000          0  1500       450       240              0          0
#
#     Groceries  internet  others  total
# 17        150       540     230   7910
# 18        200       600       0   8705
# 19        150      1200      45   8352
# 20        250        80     120   7300
# 21        120       450     170   7930

# %%
# 3. Distribution plot-  checking how well a variable is distributed in the dataset

sns.distplot(dataset['total'], color = 'r')
plt.title('Total Per Week Distribution', fontsize = 16)
plt.xlabel('Total Expense', fontsize = 14)
plt.ylabel('Frequency', fontsize = 14)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)

plt.savefig('static/distplot.png')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## Analysing the shape of the dataset using skewness and kurtosis

# %%
print('Printing Skewness and Kurtosis for all columns')
print()
for col in list(dataset.columns):
    print('{0} : Skewness {1:.3f} and  Kurtosis {2:.3f}'.format(col,dataset[col].skew(),dataset[col].kurt()))
# Out:
# Printing Skewness and Kurtosis for all columns
#
# Housing : Skewness 3.884 and  Kurtosis 15.582
# Transport : Skewness 1.386 and  Kurtosis 1.316
# Food : Skewness 2.511 and  Kurtosis 7.947
# shopping : Skewness 4.548 and  Kurtosis 21.065
# Payments : Skewness 4.514 and  Kurtosis 20.824
# Entertainment : Skewness 2.220 and  Kurtosis 3.918
# Utilities : Skewness 2.128 and  Kurtosis 4.644
# Groceries : Skewness 1.308 and  Kurtosis 3.386
# internet : Skewness 1.622 and  Kurtosis 4.417
# others : Skewness 0.605 and  Kurtosis -1.245
# total : Skewness 1.516 and  Kurtosis 1.524

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['Housing'])
plt.title('Plot for Housing')
plt.xlabel('Housing')
plt.ylabel('Count')
plt.savefig('./static/skewhousing')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['Food'])
plt.title('Plot for Food')
plt.xlabel('Food')
plt.ylabel('Count')
plt.savefig('./static/skewfood')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['shopping'])
plt.title('Plot for Shopping')
plt.xlabel('shopping')
plt.ylabel('Count')
plt.savefig('./static/skewshopping')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['Transport'])
plt.title('Plot for Transport')
plt.xlabel('Transport')
plt.ylabel('Count')
plt.savefig('./static/skewtransport')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['Utilities'])
plt.title('Plot for Utilities')
plt.xlabel('Utilities')
plt.ylabel('Count')
plt.savefig('./static/skewutilities')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['Payments'])
plt.title('Plot for Payments')
plt.xlabel('Payments')
plt.ylabel('Count')
plt.savefig('./static/skewpayments')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['Entertainment'])
plt.title('Plot for Entertainment')
plt.xlabel('Entertainment')
plt.ylabel('Count')
plt.savefig('./static/skewentertainment')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['others'])
plt.title('Plot for Others')
plt.xlabel('Others')
plt.ylabel('Count')
plt.savefig('./static/skewothers')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['Groceries'])
plt.title('Plot for Groceries')
plt.xlabel('Groceries')
plt.ylabel('Count')
plt.savefig('./static/skewgroceries')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['internet'])
plt.title('Plot for Internet')
plt.xlabel('Internet')
plt.ylabel('Count')
plt.savefig('./static/skewinternet')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['total'])
plt.title('Plot for total Expense')
plt.xlabel('Total')
plt.ylabel('Count')
plt.savefig('./static/skewtotal')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
dataset.head()
# Out:
#    Housing  Transport  Food  shopping  Payments  Entertainment  Utilities  \
# 0     5000       1500  4000       300        20             20       2000
# 1     5000       1200  2500       200        10            120       1300
# 2     6000       2300  1200        45       300             15        300
# 3     7500       1200   700         0       120            350        250
# 4     5000        200   500       570         0            100          0
#
#    Groceries  internet  others  total
# 0        200       250     120  13410
# 1        120       350       0  10800
# 2          0       350       0  10510
# 3        120       220       0  10460
# 4         40       270     500   7180

# %% [markdown]
# ## MODEL BUILDING

# %% [markdown]
# ## Training the Dataset

# %%
#Splitting Training and Test Set

# %%
# FEATURE SELECTION & DATA SPLIT
from sklearn.model_selection import train_test_split # data split

from sklearn.linear_model import LinearRegression # OLS algorithm
from sklearn.linear_model import Ridge # Ridge algorithm
from sklearn.linear_model import Lasso # Lasso algorithm
from sklearn.linear_model import BayesianRidge # Bayesian algorithm
from sklearn.linear_model import ElasticNet # ElasticNet algorithm

from sklearn.metrics import explained_variance_score as evs # evaluation metric
from sklearn.metrics import r2_score as r2 # evaluation metric

sns.set_style('whitegrid') # plot style
plt.rcParams['figure.figsize'] = (20, 10) # plot size
from termcolor import colored as cl # text customization

X_var = dataset[['Housing', 'Transport', 'Food', 'shopping','Payments', 'Entertainment','Utilities','Groceries', 'internet', 'others']].values
y_var = dataset['total'].values

X_train, X_test, y_train, y_test = train_test_split(X_var, y_var, test_size = 0.2, random_state = 0)

print(cl('X_train samples : ', attrs = ['bold']), X_train[0:5])
print(cl('X_test samples : ', attrs = ['bold']), X_test[0:5])
print(cl('y_train samples : ', attrs = ['bold']), y_train[0:5])
print(cl('y_test samples : ', attrs = ['bold']), y_test[0:5])
# Out:
# X_train samples :  [[5000    0 1500  450  240    0    0  120  450  170]
#  [5000  120  590  150    0  500    0   70  150    0]
#  [5000  250  987    0  600    0  120  150 1200   45]
#  [5000  120  250    0  560    0  700   80  459  450]
#  [5000  120  570  350  600    0  600  110  450  500]]
# X_test samples :  [[5000  500 1200    0  150    0    0  250   80  120]
#  [5000 1500 1200    0    0    0    0  120  600  450]
#  [5000  150 1100  570   45    0    0  120  450  230]
#  [5000  600 1000 8000    0    0    0  350  120  560]
#  [5000 1200 2500  200   10  120 1300  120  350    0]]
# y_train samples :  [7930 6580 8352 7619 8300]
# y_test samples :  [ 7300  8870  7665 15630 10800]

# %%
# MODELING

# 1. OLS

ols = LinearRegression()
ols.fit(X_train, y_train)
ols_yhat = ols.predict(X_test)

# 2. Ridge

ridge = Ridge(alpha = 0.5)
ridge.fit(X_train, y_train)
ridge_yhat = ridge.predict(X_test)

# 3. Lasso

lasso = Lasso(alpha = 0.01)
lasso.fit(X_train, y_train)
lasso_yhat = lasso.predict(X_test)

# 4. Bayesian

bayesian = BayesianRidge()
bayesian.fit(X_train, y_train)
bayesian_yhat = bayesian.predict(X_test)

# 5. ElasticNet

en = ElasticNet(alpha = 0.01)
en.fit(X_train, y_train)
en_yhat = en.predict(X_test)

# %%
# 1. Explained Variance Score

print(cl('EXPLAINED VARIANCE SCORE:', attrs = ['bold']))
print('-------------------------------------------------------------------------------')
print(cl('Explained Variance Score of OLS model is {}'.format(evs(y_test, ols_yhat)), attrs = ['bold']))
print('-------------------------------------------------------------------------------')
print(cl('Explained Variance Score of Ridge model is {}'.format(evs(y_test, ridge_yhat)), attrs = ['bold']))
print('-------------------------------------------------------------------------------')
print(cl('Explained Variance Score of Lasso model is {}'.format(evs(y_test, lasso_yhat)), attrs = ['bold']))
print('-------------------------------------------------------------------------------')
print(cl('Explained Variance Score of Bayesian model is {}'.format(evs(y_test, bayesian_yhat)), attrs = ['bold']))
print('-------------------------------------------------------------------------------')
print(cl('Explained Variance Score of ElasticNet is {}'.format(evs(y_test, en_yhat)), attrs = ['bold']))
print('-------------------------------------------------------------------------------')
# Out:
# EXPLAINED VARIANCE SCORE:
# -------------------------------------------------------------------------------
# Explained Variance Score of OLS model is 1.0
# -------------------------------------------------------------------------------
# Explained Variance Score of Ridge model is 0.9999999999973324
# -------------------------------------------------------------------------------
# Explained Variance Score of Lasso model is 0.9999999994431615
# -------------------------------------------------------------------------------
# Explained Variance Score of Bayesian model is 1.0
# -------------------------------------------------------------------------------
# Explained Variance Score of ElasticNet is 0.9999999994432265
# -------------------------------------------------------------------------------

# %%
X_train= dataset.iloc[:, :10] ## indexed based selecting method which means that we have to
## pass integer index in the method to select specific row/column
y_train= dataset.iloc[:, -1]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %% [markdown]
# # Fitting model with trainig data

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_train,y_train) ##  computes the accuracy score
# Out:
# 1.0

# %% [markdown]
# ## PICKLE MODEL

# %%
pickle.dump(regressor, open('model.pkl','wb'))  # Saving model to disk

# %%
model = pickle.load(open('model.pkl','rb'))
print(model.predict([[2, 9, 6,4,8,4,4,3,4,7]]))
# Out:
# [51.]
